// %%
 // Question a How many letters are there in 'Supercalifragilisticexpialidocious'?
        string data = "Supercalifragilisticexpialidocious";
        int letterCount = data.Length;
        Console.WriteLine("Total letters in Word : " + letterCount);

        // Question b Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
        string phrase = "Supercalifragilisticexpialidocious";
        bool containsSubstring = phrase.Contains("ice");
        Console.WriteLine("\n \n It contains 'ice' as a substring: " + containsSubstring);

        // Question c Which of the following words is the longest: Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
       // Bababadalgharaghtakamminarronnkonn?
        string[] words = { "Supercalifragilisticexpialidocious", "Honorificabilitudinitatibus", "Bababadalgharaghtakamminarronnkonn" };
        string lword = "";
        foreach (string w in words)
        {
            if (w.Length > lword.Length)
                lword = w;
        }
        Console.WriteLine("\n\n The longest word among the given options: " + lword);

        // Question d Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
        //'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'.Which one comes last ?
                string[] composers = { "Berlioz", "Borodin", "Brian", "Bartok", "Bellini", "Buxtehude", "Bernstein" };
        Array.Sort(composers);
        Console.WriteLine("\n First composer: " + composers[0]);
        Console.WriteLine("\n Last composer: " + composers[composers.Length - 1]);
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-3934.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
// ...
